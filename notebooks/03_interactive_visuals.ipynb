# %%
import pandas as pd
import plotly.express as px
import folium

# %%
import sys
import os

# Add project root to Python path
sys.path.append(os.path.abspath(".."))

from src.preprocess import load_data, clean_data, feature_engineering

# %%
# --- Load and preprocess ---
path = r"C:\Users\a12u\OneDrive\Desktop\Courses\IBM Data Science\Data Visualization with python\media-consumption-analysis\data\raw\netflix_titles.csv"
df = load_data(path)
df = clean_data(df)
df = feature_engineering(df)

# %% [markdown]
# --- 1. Interactive bar chart: Top 10 genres ---

# %%
top_genres = df['primary_genre'].value_counts().head(10).reset_index()
top_genres.columns = ['Genre', 'Count']

fig = px.bar(
    top_genres,
    x='Count',
    y='Genre',
    orientation='h',
    color='Count',
    color_continuous_scale='Viridis',
    title="Top 10 Genres on Netflix (Interactive)"
)
fig.show()

# %% [markdown]
# --- 2. Timeline: Content added per year ---

# %%
yearly = df['year_added'].value_counts().sort_index().reset_index()
yearly.columns = ['Year', 'Count']

fig2 = px.line(
    yearly,
    x='Year',
    y='Count',
    markers=True,
    title="Content Added to Netflix Over Time"
)
fig2.show()

# %% [markdown]
# --- 3. Interactive map: Countries producing Netflix content ---

# %%
import pandas as pd

cities_df = pd.read_excel(r"C:\Users\a12u\OneDrive\Desktop\Courses\IBM Data Science\Data Visualization with python\media-consumption-analysis\data\worldcities.xlsx")
cities_df.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6870  139.7495      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
capital_coords = (
    cities_df[cities_df['capital'] == 'primary']
    .groupby('country')[['lat', 'lng']]
    .mean()
    .round(4)
    .reset_index()
    .set_index('country')
    .T
    .to_dict()
)

# %%
world_map = folium.Map(location=[20, 0], zoom_start=2)

for country, count in df['country'].value_counts().items():
    if country in capital_coords:
        coords = [capital_coords[country]['lat'], capital_coords[country]['lng']]
        folium.CircleMarker(
            location=coords,
            radius=count / 50,
            popup=f"{country}: {count}",
            color='blue',
            fill=True,
            fill_color='blue'
        ).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2034b50751c9de1cc75fd59ba6aba6fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2034b50751c9de1cc75fd59ba6aba6fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2034b50751c9de1cc75fd59ba6aba6fc = L.map(
#                 &quot;map_2034b50751c9de1cc75fd59ba6aba6fc&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1679216e33112dc136abe88dab05026 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1679216e33112dc136abe88dab05026.addTo(map_2034b50751c9de1cc75fd59ba6aba6fc);
#
#
#             var circle_marker_946aa120858240fe3b0a2201b0690b7c = L.circleMarker(
#                 [38.9047, -77.0163],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 56.36, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2034b50751c9de1cc75fd59ba6aba6fc);
#
#
#         var popup_0e37374cfdd3ad671d57b91435547875 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af014d169a554478bc9b9b2462ff9a50 = $(`&lt;div id=&quot;html_af014d169a554478bc9b9b2462ff9a50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United States: 2818&lt;/div&gt;`)[0];
#                 popup_0e37374cfdd3ad671d57b91435547875.setContent(html_af014d169a554478bc9b9b2462ff9a50);
#
#
#
#         circle_marker_946aa120858240fe3b0a2201b0690b7c.bindPopup(popup_0e37374cfdd3ad671d57b91435547875)
#         ;
#
#
#
#
#             var circle_marker_46864b152296dcd18c201a6dbb764c73 = L.circleMarker(
#                 [28.6139, 77.2089],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19.44, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2034b50751c9de1cc75fd59ba6aba6fc);
#
#
#         var popup_db1c87509146923bd416919bb13aff09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8109fcf6eb1031dcef19bdfd54422858 = $(`&lt;div id=&quot;html_8109fcf6eb1031dcef19bdfd54422858&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;India: 972&lt;/div&gt;`)[0];
#                 popup_db1c87509146923bd416919bb13aff09.setContent(html_8109fcf6eb1031dcef19bdfd54422858);
#
#
#
#         circle_marker_46864b152296dcd18c201a6dbb764c73.bindPopup(popup_db1c87509146923bd416919bb13aff09)
#         ;
#
#
#
#
#             var circle_marker_2df8b55dfd25a57cea9589a26c888afa = L.circleMarker(
#                 [51.5072, -0.1275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.38, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2034b50751c9de1cc75fd59ba6aba6fc);
#
#
#         var popup_d634d0120a4adc0da730b1b6813228ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2dce6d8e2f92621b7923ca8098da9f5 = $(`&lt;div id=&quot;html_d2dce6d8e2f92621b7923ca8098da9f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United Kingdom: 419&lt;/div&gt;`)[0];
#                 popup_d634d0120a4adc0da730b1b6813228ef.setContent(html_d2dce6d8e2f92621b7923ca8098da9f5);
#
#
#
#         circle_marker_2df8b55dfd25a57cea9589a26c888afa.bindPopup(popup_d634d0120a4adc0da730b1b6813228ef)
#         ;
#
#
#
#
#             var circle_marker_de809917b74279e5ea7b89217c130d6e = L.circleMarker(

# %%
world_map.save(r"C:\Users\a12u\OneDrive\Desktop\Courses\IBM Data Science\Data Visualization with python\media-consumption-analysis\notebooks\images\netflix_map.html")
